# %%
from transformers import Trainer, AutoModelForCausalLM

# %%
import inspect 
inspect.getsourcefile(AutoModelForCausalLM)
# Out:
# '/Users/morizin/Documents/Code/jigsaw-competition/.venv/lib/python3.13/site-packages/transformers/models/auto/modeling_auto.py'

# %%
from transformers import Training
